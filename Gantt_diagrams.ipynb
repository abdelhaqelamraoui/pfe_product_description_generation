# %%
from tkinter import font
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator

# Data for the Gantt chart
tasks_data = {
    "TASK NAME": [
        "Recherche du sujet",
        "Définition de la problématique",
        "Étude de faisabilité",
        "Validation du sujet",
        "Recherche de données disponibles",
        "Scraping des données",
        "Nettoyage des données",
        "Analyse exploratoire",
        "Analyse des Articles",
        "Étude de modèles existants",
        "Choix du modèle adapté",
        "Implémentation du modèle",
        "Entraînement sur les données",
        "Évaluation du modèle",
        "Développement technique",
        "Rédaction du rapport"
    ],
    "START DATE": [
        "2025-03-05", "2025-03-11", "2025-03-15", "2025-03-23", "2025-03-28",
        "2025-04-01", "2025-04-06", "2025-04-10", "2025-04-14", "2025-04-18",
        "2025-04-23", "2025-04-26", "2025-05-02", "2025-05-08", "2025-05-12",
        "2025-05-08"
    ],
    "END DATE": [
        "2025-03-12", "2025-03-14", "2025-03-21", "2025-03-28", "2025-04-02",
        "2025-04-07", "2025-04-09", "2025-04-15", "2025-04-17", "2025-04-24",
        "2025-04-25", "2025-05-02", "2025-05-09", "2025-05-13", "2025-05-19",
        "2025-06-04"
    ]
}

# Create DataFrame
df = pd.DataFrame(tasks_data)
df["START DATE"] = pd.to_datetime(df["START DATE"])
df["END DATE"] = pd.to_datetime(df["END DATE"])

# Reverse the order of tasks for correct top-down plotting
df = df[::-1]

# Create a Gantt chart
fig, ax = plt.subplots(figsize=(16, 8))
for i, task in df.iterrows():
    ax.barh(task["TASK NAME"], (task["END DATE"] - task["START DATE"]
                                ).days, left=task["START DATE"], color="skyblue")

ax.xaxis_date()
ax.xaxis.set_major_locator(MaxNLocator(integer=True))
ax.set_xlabel("\nDate")
ax.set_ylabel("Tâche")
ax.set_title("\nDiagramme de Gantt Prévisionnel", fontsize=16, pad=20)
plt.xticks(rotation=0, fontsize=12)
plt.yticks(rotation=0, fontsize=12)
plt.grid(axis="both", linestyle="--", alpha=0.4)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator

# New data
tasks_data = {
    "TASK ID": list(range(1, 17)),
    "TASK NAME": [
        "Recherche du sujet",
        "Définition de la problématique",
        "Étude de faisabilité",
        "Validation du sujet",
        "Recherche de données disponibles",
        "Scraping des données",
        "Nettoyage des données",
        "Analyse exploratoire",
        "Analyse des Articles",
        "Étude de modèles existants",
        "Choix du modèle adapté",
        "Implémentation du modèle",
        "Entraînement sur les données",
        "Évaluation du modèle",
        "Développement technique",
        "Rédaction du rapport"
    ],
    "START DATE": [
        "2025-03-05", "2025-03-16", "2025-03-19", "2025-03-23",
        "2025-03-25", "2025-03-28", "2025-04-18", "2025-04-26",
        "2025-05-02", "2025-04-18", "2025-04-25", "2025-04-30",
        "2025-05-02", "2025-05-16", "2025-05-20", "2025-05-08"
    ],
    "WORK DAYS": [12, 4, 6, 4, 4, 20, 8, 6, 4, 8, 6, 8, 12, 4, 10, 20],
    "END DATE": [
        "2025-03-20", "2025-03-19", "2025-03-26", "2025-03-26",
        "2025-03-28", "2025-04-24", "2025-04-29", "2025-05-02",
        "2025-05-07", "2025-04-29", "2025-05-02", "2025-05-09",
        "2025-05-19", "2025-05-21", "2025-06-02", "2025-06-04"
    ]
}

# Create DataFrame
df = pd.DataFrame(tasks_data)
df["START DATE"] = pd.to_datetime(df["START DATE"])
df["END DATE"] = pd.to_datetime(df["END DATE"])

# Reverse order for top-down plotting
df = df[::-1]

# Create Gantt chart
fig, ax = plt.subplots(figsize=(16, 8))
for i, task in df.iterrows():
    ax.barh(task["TASK NAME"], (task["END DATE"] - task["START DATE"]).days,
            left=task["START DATE"], color="skyblue")

ax.xaxis_date()
ax.xaxis.set_major_locator(MaxNLocator(integer=True))
ax.set_xlabel("\nDate")
ax.set_ylabel("Tâche")
ax.set_title("\nDiagramme de Gantt Réel", fontsize=16, pad=20)
plt.xticks(rotation=0, fontsize=12)
plt.yticks(rotation=0, fontsize=12)
plt.grid(axis="both", linestyle="--", alpha=0.4)
plt.tight_layout()
plt.show()
